# %% [markdown]
# # Pandas Data Analysis**
# ---
# ### **Description**
# - Data Exploratioin and Manipulation using Pandas
# - Dataset: Iris
#
#
#
# ### **Lab Structure**
# **Part 1**: [Reading Datasets](#p1)
#
# **Part 2**: [Exploring Datasets](#p2)
#
# **Part 3**: [DataFrame Attributes](#p3)
#
# **Part 4**: [Most Common and Unique Values](#p4)
#
# **Part 5**: [Check Your Understadning](#p5)
#
# **Part 6**: [Working with Rows and Columns](#p6)
#
# **Part 7**: [Exploring the Mean, Median, and Sum](#p7)
#
# <br>
#
#
# ### **Resources**
# * [10 mins Pandas](https://pandas.pydata.org/docs/user_guide/10min.html)
#
# <br>

# %%
# !pip install pandas
import pandas as pd

# !pip install scikit-learn
from sklearn import datasets

# %% [markdown]
# <a name="p1"></a>
#
# ---
# ## **Part 1: Reading Datasets**
# ---

# %% [markdown]
# # Iris Dataset Overview
#
# The **Iris dataset** is one of the most popular datasets used in machine learning and statistics. It contains information about three species of iris flowers and is often used for classification tasks.
#
# ## Dataset Overview
# - **Number of Instances**: 150
# - **Number of Features**: 4 numeric, continuous features
# - **Number of Classes**: 3 (Iris Setosa, Iris Versicolor, Iris Virginica)
#
# ## Feature Names
# 1. Sepal Length (cm)
# 2. Sepal Width (cm)
# 3. Petal Length (cm)
# 4. Petal Width (cm)
#
# ## Target Variable
# Labels corresponding to the species of iris:
# - `0`: Iris Setosa
# - `1`: Iris Versicolor
# - `2`: Iris Virginica
#
# ### Dataset Description
# The dataset is built into scikit-learn and can be loaded using sklearn.datasets.load_iris().
#
# ```
# from sklearn.datasets import load_iris
#
# # Load Iris dataset
# iris = load_iris()
#
# # Features and target
# X = iris.data
# y = iris.target
#
# # Dataset Description
# print(iris.DESCR)
# ```
# ## Structure of the Dataset
#
# - **`iris.data` (Features)**: A 2D NumPy array of shape `(150, 4)` containing feature values.
# - **`iris.target` (Labels)**: A 1D NumPy array of shape `(150,)` containing class labels.
# - **`iris.feature_names`**: List of feature names.
# - **`iris.target_names`**: List of target class names.

# %%
# The figure below is stored in this lab's GitHub repo. Download it once into this
# Colab session, then open it as a local file.
# !wget -q -O iris.png https://raw.githubusercontent.com/DVC-COMSC/PythonPandas/main/png/iris.png

from IPython.display import Image
Image("iris.png")

# %% [markdown]
# #### **Problem #1.1**
# Before beginning the practice problems, read the description above and run the code below to import to load the data. Take a look at the resulting DataFrame.

# %%
# Load dataset (actual data with associated documentation)
iris = datasets.load_iris()

# View the raw data
print(iris)

# Create DataFrame
iris_df = pd.DataFrame(data=iris.data,columns=iris.feature_names)

# Add target to dataset
iris_df['target'] = iris.target_names[iris.target]

# View the structured DataFrame
print('\n')
print('\n')
print(iris_df)

# %%
iris_df.describe()
iris_df.columns

# %% [markdown]
# #### ‼️ <mark> Save your work here </mark>

# %% [markdown]
# <a name="p2"></a>
#
# ---
# ## **Part 2: Exploring Datasets**
# ---
# Before diving into data manipulation, let's take an initial look at our dataset by examining the first several rows and columns. This preliminary step will help us grasp the structure and context of the data we're working with.

# %% [markdown]
# #### **Problem #2.1**
#
# ** let's see what `.head()` tells us about this DataFrame.

# %%
iris_df.head()

# %% [markdown]
# #### **Problem #2.2**
#
# ** let's look at the first **10** rows.

# %%
# iris_df.# COMPLETE THIS LINE
iris_df.head(10)

# %% [markdown]
# #### **Problem #2.3**
#
# ** let's determine what the datatype of the target column is.

# %%
iris_df.dtypes

# %% [markdown]
# #### **Problem #2.4**
#
# ** let's determine what the largest and smallest sepal lengths are.

# %%
print (max(iris_df['sepal length (cm)']))
print (min(iris_df['sepal length (cm)']))

# %%
iris_df['sepal length (cm)'].min()

# %%
iris_df['sepal length (cm)'].max()

# %% [markdown]
# ---
# #### **Try Problems #2.5 - 2.7 on your own.**
# ---

# %% [markdown]
# #### **Problem #2.5**
#
# **Independently**, determine the average petal length and average petal width.

# %%
iris_df['petal length (cm)'].mean()

# %%
iris_df['petal width (cm)'].mean()

# %% [markdown]
# #### **Problem #2.6**
#
#
#
# **Independently**, determine the largest and smallest `petal width (cm)`.

# %%
# COMPLETE THIS LINE
print (iris_df['petal width (cm)'].max())
print (iris_df['petal width (cm)'].min())

# %% [markdown]
# #### ** Problem #2.7**
#
# **Challenge:** If `head()` allows us to peak at the first rows of a DataFrame, what do you suppose would show us the *last* rows?
#
# If you have an idea, give it a shot below!

# %%
iris_df.tail()

# %% [markdown]
# #### ‼️ <mark> Save your work here </mark>

# %% [markdown]
# <a name="p3"></a>
#
# ---
# ## **Part 3: DataFrame Attributes**
# ---

# %% [markdown]
# #### **Problem #3.1**
#
# ** determine the number of rows and columns in the DataFrame.

# %%
# Number of rows and columns in the DataFrame
iris_df.describe
iris_df.info
iris_df.shape

# %% [markdown]
# #### **Problem #3.2**
#
# ** let's determine the total number of data elements or the *size* of the DataFrame.

# %%
# Size of the DataFrame
iris_df.size

# %% [markdown]
# #### **Problem #3.3**
#
# ** let's determine the name of the first column.

# %%
iris_df.columns[0]

# %% [markdown]
# #### **Problem #3.4**
#
# ** let's display the values from the 7th row.

# %%
iris_df.iloc[6]

# %% [markdown]
# ---
# #### **Try Problems #3.5 - 3.6 on your own.**
# ---

# %% [markdown]
# #### **Problem #3.5**
#
# ** determine the names of all columns.

# %%
iris_df.columns

# %% [markdown]
# #### **Problem #3.6**
#
# ** determine the name of the third column.

# %%
third = iris_df.columns[2]
third

# %% [markdown]
# #### ‼️ <mark> save your work </mark>

# %% [markdown]
# <a name="p4"></a>
#
# ---
# ## **Part 4: Most Common and Unique Values**
# ---
# In Part 4, we will continue exploring the Iris dataset.

# %% [markdown]
# #### **Problem #4.1**
#
# **Together**, let's determine which sepal width value appears 9 times in this dataset.

# %%
# Sepal width that appears 9 times
value_count = iris_df['sepal width (cm)'].value_counts()

# %% [markdown]
# #### **Problem #4.2**
#
# **Together**, let's determine what the different iris species included in the dataset are.

# %%
# What are the different iris species included in the dataset?
iris_df['target'].value_counts()
iris_df['target'].unique()

# %% [markdown]
# ---
# #### **Try Problems #4.3 - 4.5 on your own.**
# ---

# %% [markdown]
# #### **Problem #4.3**
#
# **Independently**, determine the most common `petal length (cm)`.

# %%
# Most common petal length
iris_df['petal length (cm)'].value_counts().max()
iris_df['petal length (cm)'].value_counts().index[0]
iris_df['petal length (cm)'].value_counts()

# %% [markdown]
# #### **Problem #4.4**
#
# **Independently**, calculate the number of unique values in the `petal length (cm)` column.

# %%
len(iris_df['petal length (cm)'].unique())

# %% [markdown]
# #### **Problem #4.5**
#
# **Independently**, determine how many of each type of iris species are in the dataset.

# %% [markdown]
# #### ‼️ <mark> save your work </mark>

# %% [markdown]
# <a name="p5"></a>
#
# ---
# ## **Part 5: Check Your Understanding**
# ---
#
#
# #### **About the Dataset**
# The price of a home in California is nearly double the national average. The California Housing Dataset is a collection of data containing information on the median house value and other features of census block groups in California. This dataset was derived from the 1990 U.S. Census, using one row per census block group. A block group is the smallest geographical unit for which the U.S. Census Bureau publishes sample data (a block group typically has a population of 600 to 3,000 people).
#
# The features are as follows:
# * `MedInc`: median income in block group (in hundreds of thousands of dollars, i.e. \$100,000)
# * `HouseAge`: median house age in block group
# * `AveRooms`: average number of rooms per household
# * `AveBedrms`: average number of bedrooms per household
# * `Population`: block group population
# * `AveOccup`: average number of household members
# * `Latitude`: block group latitude
# * `Longtitude`: block group longitude
# * `TARGET`: median house value for California districts (in hundreds of thousands of dollars, i.e. $100,000)
#
# #### **Your Task**
#
# Explore the **California Housing Dataset** using the techniques you've learned so far.
#
# <br>
#
# **Before continuing, run the cell below to load the DataFrame.**

# %%
# Load dataset
cali_housing = datasets.fetch_california_housing()

# Create DataFrame
ca_df = pd.DataFrame(data=cali_housing.data,columns=cali_housing.feature_names)

# Add target to dataset
ca_df[cali_housing.target_names[0]] = cali_housing.target

# %% [markdown]
# #### **Problem #5.1**
#
# Preview the first several rows of the DataFrame.

# %%
ca_df.head()

# %% [markdown]
# #### **Problem #5.2**
#
# Determine the number of feature columns and their names.

# %%
ca_df.info

# %% [markdown]
# #### **Problem #5.3**
#
# Determine the types of data that were recorded for each of the columns.

# %% [markdown]
# #### **Problem #5.4**
#
# Determine the number of instances recorded. (How many rows are in the DataFrame?)

# %% [markdown]
# #### **Problem #5.5**
#
# Display only the values in the 15th row.

# %% [markdown]
# #### **Problem #5.6**
#
# Determine how many unique longitudinal points there are.

# %% [markdown]
# #### **Problem #5.7**
#
# Determine the most common house age.

# %% [markdown]
# #### ‼️ <mark> save your work </mark>

# %% [markdown]
# <a name="p6"></a>
#
# ---
# ## **Part 6: Working with Rows and Columns**
# ---
# #### **About the Dataset**
#
# The Linnerud dataset is a small but useful dataset that consists of data on three different exercises performed by 20 middle-aged men at a fitness center. The three exercise variables included in the dataset are `chins`, `situps`, and `jumps`.
#
# - `chins`: number of chin-ups performed by each participant
# - `situps`: number of sit-ups performed by each participant
# - `jumps`: number of jumping jacks performed by each participant
#
# By analyzing the data, we can gain insights into which exercises are most effective at building strength and endurance in this population.
#
# <br>
#
# **Run the following code before answering the questions below.**

# %%
 # import pandas as pd
import pandas as pd

# Import datasets submodule
from sklearn import datasets

# Load dataset (actual data with associated documentation)
linnerud = datasets.load_linnerud()

# Create DataFrame
linnerud_df = pd.DataFrame(data=linnerud.data,columns=linnerud.feature_names)
linnerud_df

# %% [markdown]
# #### **Problem #6.1**
#
# ** let's determine what the 16th value for `Chins` is.
#
# <br>
#
# **NOTE**: There are numerous ways to select and display a specific value. Remember, **Python uses 0-based indexing**, so the 16th row has an index of 15. You can either access only the 16th row to retrieve the 16th value, *or* you can select the 16th row and 1st column.

# %%
linnerud_df.iloc[15]['Chins']

# %% [markdown]
# #### **Problem #6.2**
#
# ** let's determine what the 9th value for `Situps` is.

# %%
linnerud_df.iloc[8]['Situps']

# %% [markdown]
# #### **Problem #6.3**
#
# ** let's print the entire fourth row.

# %%
# Print the entire fourth row
linnerud_df.iloc[3]

# %% [markdown]
# #### **Problem #6.4**
#
# ** let's print the `Jumps` column.

# %%
# Print the Jumps column
linnerud_df['Jumps']

# %% [markdown]
# #### **Problem #6.5**
#
# ** let's print the 12th-16th rows.

# %%
# Print the 12th-16th rows
linnerud_df.iloc[11:15]

# %% [markdown]
# ---
# #### **Try Problems #6.6 - 6.12 on your own.**
# ---

# %% [markdown]
# #### **Problem #6.6**
#
# ** extract rows 10 to 15 of the dataset.

# %%
# code here

# %% [markdown]
# #### **Problem #6.7**
#
# ** extract the `Situps` and `Jumps` columns of the dataset.

# %%
# code here

# %% [markdown]
# #### **Problem #6.8**
#
# ** Extract rows where the `Situps` count is greater than 100.

# %%
# Code here

# %% [markdown]
# #### **Problem #6.9**
#
# ** access the value in the third row and second column of the dataset.

# %%
# Code here

# %% [markdown]
# #### **Problem #6.10**
#
# ** determine the 17th value for `Jumps`.

# %%
linnerud_df['Jumps'][16]

# %% [markdown]
# #### **Problem #6.11**
#
# ** extract rows where the `Chins` count is greater than 6.

# %%
linnerud_df[linnerud_df['Chins']>6]

# %% [markdown]
# #### **Problem #6.12**
#
# **Independently**, extract rows 6-10 for the `Chins` and `Jumps` columns.

# %%
# Extract rows 6-10 of the dataset for the Chins and Jumps columns
# code here

# %% [markdown]
# #### ‼️ <mark> Save your work here </mark>

# %% [markdown]
# <a name="p7"></a>
#
# ---
# ## **Part 7: Exploring the Mean, Median and Sum**
# ---

# %% [markdown]
# #### **Problem #7.1**
#
# ** let's find the mean  for `Jumps`.
#
# <br>

# %%
linnerud_df['Jumps'].mean()

# %% [markdown]
# #### **Problem #7.2**
#
# ** let's find the median  for `Jumps`.

# %% [markdown]
# #### **Problem #7.3**
# ** let's find the sum  for `Jumps`.

# %% [markdown]
# ---
# #### **Try Problems #7.4 - 7.6 on your own.**
# ---

# %% [markdown]
# #### **Problem #7.4**
#
# ** find the mean for `Situps`.

# %% [markdown]
# #### **Problem #7.5**
#
# ** find the median for `Situps`.

# %% [markdown]
# #### **Problem #7.6**
#
# ** find the sum for `Situps`.

# %% [markdown]
# #### ‼️ <mark> save your work </mark>
